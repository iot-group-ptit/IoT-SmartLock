# %% [markdown]
# ## test api verify

# %%
import base64
import requests

def image_to_base64(image_path):
    with open(image_path, "rb") as img_file:
        base64_string = base64.b64encode(img_file.read()).decode("utf-8")
    return base64_string


# ----- 1. Chuyển ảnh sang base64 -----
path = r"/content/dao_thi_huyen_2.jpg"
b64_image = image_to_base64(path)


# ----- 2. Gọi API verify -----
url = "https://baptismally-nettable-ozie.ngrok-free.dev/verify"

payload = {
    "image_base64": b64_image
}

response = requests.post(url, json=payload)

# ----- 3. Check action-----
print("Kết quả API:")
result = response.json()
print(result)
if result.get("verified") == True:

    initial_x = result.get("initial_x")
    url_action = "https://baptismally-nettable-ozie.ngrok-free.dev/check-action"
    left_path = r"/content/left.jpg"
    b64_image_left = image_to_base64(left_path)

    payload_action = {
        "initial_x": initial_x,
        "direction": "left",
        "image_base64" : b64_image_left
    }
    response_action = requests.post(url_action, json=payload_action)
    result_action = response_action.json()
    print("Kết quả check action:")
    print(result_action)
# Out:
# Kết quả API:
# {'initial_x': 976.6099853515625, 'person': 'FACE005', 'similarity': 0.7486000061035156, 'verified': True}
# Kết quả check action:
# {'delta': -595.5908813476562, 'moved': True}

# %% [markdown]
# ## test api register

# %%
import base64
import requests

def image_to_base64(image_path):
    with open(image_path, "rb") as img_file:
        base64_string = base64.b64encode(img_file.read()).decode("utf-8")
    return base64_string


# ----- 1. Chuyển ảnh sang base64 -----
path = r"/content/dthuyen.png"
b64_image = image_to_base64(path)


# ----- 2. Gọi API verify -----
url = "https://blair-unpractised-tia.ngrok-free.dev/register"

payload = {
    "image_base64": b64_image,
    'user_id' : 'daothihuyen'
}

response = requests.post(url, json=payload)

# ----- 3. Check action-----
print("Kết quả API:")
result = response.json()
print(result)
# Out:
# Kết quả API:
# {'db_id': '693467ae281fe88d3003ae86', 'face_id': 'FACE_004', 'message': 'Đăng ký khuôn mặt thành công', 'status': 'success'}

# %% [markdown]
# ## test api delete

# %%
import base64
import requests



# ----- 2. Gọi API verify -----
url = "https://blair-unpractised-tia.ngrok-free.dev/delete-face"

payload = {
    'user_id' : 'daothihuyen'
}

response = requests.post(url, json=payload)

# ----- 3. Check action-----
print("Kết quả API:")
result = response.json()
print(result)
# Out:
# Kết quả API:
# {'deleted': 1, 'message': 'Đã xoá tất cả khuôn mặt của user_id daothihuyen', 'status': 'success'}
